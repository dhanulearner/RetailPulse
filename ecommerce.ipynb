# %% [markdown]
# ## Importing the required libraries

# %%
import pandas as pd 
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Loading the data from the CSV

# %%
df = pd.read_excel("C:\\Users\\91832\\Downloads\\DataSetforPythonLibraries (1).xlsx")

# %% [markdown]
# ## Displaying the first 5 rows of the DataFrame

# %%
df.head()
# Out:
#     USER_ID           ORDER_ID          PURCHASE_TS    SHIP_TS  \
# 0  2c06175e   0001328c3c220830  2020-12-24 00:00:00 2020-12-13
# 1  ee8e5bc2  0002af7a5c6100772  2020-10-01 00:00:00 2020-09-21
# 2  9eb4efe0   0002b8350e167074  2020-04-21 00:00:00 2020-02-16
# 3  cac7cbaf   0006d06b98385729  2020-04-07 00:00:00 2020-04-04
# 4  6b0230bc   00097279a2f46150  2020-11-24 00:00:00 2020-08-02
#
#                 PRODUCT_NAME PRODUCT_ID  USD_PRICE PURCHASE_PLATFORM  \
# 0            Nintendo Switch       e682     168.00           website
# 1            Nintendo Switch       e682     160.61           website
# 2            Nintendo Switch       8d0d     151.20           website
# 3  Sony PlayStation 5 Bundle       54ed    1132.82           website
# 4            Nintendo Switch       8d0d      33.89           website
#
#   MARKETING_CHANNEL ACCOUNT_CREATION_METHOD COUNTRY_CODE
# 0         affiliate                 unknown           US
# ...

# %% [markdown]
# ## to find the bottom 5 element

# %%
df.tail()
# Out:
#         USER_ID           ORDER_ID          PURCHASE_TS    SHIP_TS  \
# 21859  e432cf6f   fff0b6a1e9996384  2019-11-27 00:00:00 2019-11-29
# 21860  f4f11c04  fff4592dc6d103535  2019-12-23 00:00:00 2019-12-26
# 21861  f4f11c04  fff4592dc6d103537  2019-12-23 00:00:00 2019-12-26
# 21862  203ce4dd   fff829b061e16171  2021-01-31 00:00:00 2021-02-02
# 21863  203ce4dd   fff829b061e16172  2021-01-31 00:00:00 2021-02-02
#
#                     PRODUCT_NAME PRODUCT_ID  USD_PRICE PURCHASE_PLATFORM  \
# 21859  Sony PlayStation 5 Bundle       54ed    1527.06           website
# 21860     27in 4K gaming monitor       891b     467.88           website
# 21861     27in 4K gaming monitor       891b     467.88           website
# 21862          Dell Gaming Mouse       8d4f      67.07        mobile app
# 21863          Dell Gaming Mouse       8d4f      67.07        mobile app
#
#       MARKETING_CHANNEL ACCOUNT_CREATION_METHOD COUNTRY_CODE
# 21859            direct                 desktop           US
# ...

# %% [markdown]
# ## to see the column list

# %%
#print(df.columns.tolist())
df.columns
# Out:
# Index(['USER_ID', 'ORDER_ID', 'PURCHASE_TS', 'SHIP_TS', 'PRODUCT_NAME',
#        'PRODUCT_ID', 'USD_PRICE', 'PURCHASE_PLATFORM', 'MARKETING_CHANNEL',
#        'ACCOUNT_CREATION_METHOD', 'COUNTRY_CODE'],
#       dtype='object')

# %% [markdown]
# ## to see the no of row and column

# %%
df.shape
# Out:
# (21864, 11)

# %% [markdown]
# ## to check the datatypes

# %%
df.dtypes
# Out:
# USER_ID                            object
# ORDER_ID                           object
# PURCHASE_TS                        object
# SHIP_TS                    datetime64[ns]
# PRODUCT_NAME                       object
# PRODUCT_ID                         object
# USD_PRICE                         float64
# PURCHASE_PLATFORM                  object
# MARKETING_CHANNEL                  object
# ACCOUNT_CREATION_METHOD            object
# COUNTRY_CODE                       object
# dtype: object

# %% [markdown]
# ## non-null columns,

# %%
df.isna().any ()
# Out:
# USER_ID                    False
# ORDER_ID                   False
# PURCHASE_TS                False
# SHIP_TS                    False
# PRODUCT_NAME               False
# PRODUCT_ID                 False
# USD_PRICE                   True
# PURCHASE_PLATFORM          False
# MARKETING_CHANNEL           True
# ACCOUNT_CREATION_METHOD     True
# COUNTRY_CODE                True
# dtype: bool

# %% [markdown]
# ## to see all the stastical information also called as 5 number summery(Minimum, Q1, Median, Q3, Maximum)

# %%
df.describe()
# Out:
#                            SHIP time     USD_PRICE
# count                          21829  21829.000000
# mean   2020-04-15 19:07:06.313619712    281.192692
# min              2018-10-18 00:00:00      0.000000
# 25%              2019-11-12 00:00:00    126.000000
# 50%              2020-05-23 00:00:00    168.000000
# 75%              2020-10-06 00:00:00    355.110000
# max              2021-11-16 00:00:00   3146.880000
# std                              NaN    366.498031

# %% [markdown]
# ## summery for all column

# %%
df.describe(include='all')
# Out:
#          USER_ID          ORDER_ID          PURCHASE_TS  \
# count      21864             21864                21864
# unique     19851             21719                  783
# top     c14ee1a5  fecc9d6766231653  2020-12-19 00:00:00
# freq           4                 2                   95
# mean         NaN               NaN                  NaN
# min          NaN               NaN                  NaN
# 25%          NaN               NaN                  NaN
# 50%          NaN               NaN                  NaN
# 75%          NaN               NaN                  NaN
# max          NaN               NaN                  NaN
# std          NaN               NaN                  NaN
#
#                               SHIP_TS     PRODUCT_NAME PRODUCT_ID  \
# count                           21864            21864      21864
# unique                            NaN                9         46
# top                               NaN  Nintendo Switch       8d0d
# ...

# %% [markdown]
# ## to find no of null vanlue

# %%
df.isnull().sum()
# Out:
# USER_ID                     0
# ORDER_ID                    0
# PURCHASE_TS                 0
# SHIP_TS                     0
# PRODUCT_NAME                0
# PRODUCT_ID                  0
# USD_PRICE                   5
# PURCHASE_PLATFORM           0
# MARKETING_CHANNEL          83
# ACCOUNT_CREATION_METHOD    83
# COUNTRY_CODE               38
# dtype: int64

# %% [markdown]
# ## replace null with mean

# %%
df = df.fillna(df.mean(numeric_only=True))
df.isnull().sum()
# Out:
# USER_ID                     0
# ORDER_ID                    0
# PURCHASE_TS                 0
# SHIP_TS                     0
# PRODUCT_NAME                0
# PRODUCT_ID                  0
# USD_PRICE                   0
# PURCHASE_PLATFORM           0
# MARKETING_CHANNEL          83
# ACCOUNT_CREATION_METHOD    83
# COUNTRY_CODE               38
# dtype: int64

# %%
df = df.fillna(df.mean)

# %% [markdown]
# ## to find unique

# %%
df.nunique()
# Out:
# USER_ID                    19851
# ORDER_ID                   21719
# PURCHASE_TS                  783
# SHIP_TS                      826
# PRODUCT_NAME                   9
# PRODUCT_ID                    46
# USD_PRICE                   3634
# PURCHASE_PLATFORM              2
# MARKETING_CHANNEL              6
# ACCOUNT_CREATION_METHOD        6
# COUNTRY_CODE                 151
# dtype: int64

# %% [markdown]
# ## To see memeory used and other info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21864 entries, 0 to 21863
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   USER_ID                  21864 non-null  object
#  1   ORDER_ID                 21864 non-null  object
#  2   PURCHASE_TS              21864 non-null  object
#  3   SHIP_TS                  21864 non-null  datetime64[ns]
#  4   PRODUCT_NAME             21864 non-null  object
#  5   PRODUCT_ID               21864 non-null  object
#  6   USD_PRICE                21864 non-null  float64
#  7   PURCHASE_PLATFORM        21864 non-null  object
#  8   MARKETING_CHANNEL        21864 non-null  object
#  9   ACCOUNT_CREATION_METHOD  21864 non-null  object
#  10  COUNTRY_CODE             21864 non-null  object
# dtypes: datetime64[ns](1), float64(1), object(9)
# memory usage: 1.8+ MB

# %% [markdown]
# ## Check or duplicates in the DataFrames if any then remove

# %%
print (df.duplicated().sum()) # to count
# Out:
# 35

# %%
df.duplicated() # to just check
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 21859    False
# 21860    False
# 21861    False
# 21862    False
# 21863    False
# Length: 21864, dtype: bool

# %%
df.drop_duplicates(inplace=True) ## to remove

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 21859    False
# 21860    False
# 21861    False
# 21862    False
# 21863    False
# Length: 21829, dtype: bool

# %%
df.dtypes
# Out:
# USER_ID                            object
# ORDER_ID                           object
# PURCHASE_TS                        object
# SHIP_TS                    datetime64[ns]
# PRODUCT_NAME                       object
# PRODUCT_ID                         object
# USD_PRICE                         float64
# PURCHASE_PLATFORM                  object
# MARKETING_CHANNEL                  object
# ACCOUNT_CREATION_METHOD            object
# COUNTRY_CODE                       object
# dtype: object

# %% [markdown]
# ## to change the column name

# %%
df=df.rename(columns={'PURCHASE_TS':'PURCHASE time','SHIP_TS':'SHIP time'})#Rename columns
df.head()
# Out:
#     USER_ID           ORDER_ID        PURCHASE time  SHIP time  \
# 0  2c06175e   0001328c3c220830  2020-12-24 00:00:00 2020-12-13
# 1  ee8e5bc2  0002af7a5c6100772  2020-10-01 00:00:00 2020-09-21
# 2  9eb4efe0   0002b8350e167074  2020-04-21 00:00:00 2020-02-16
# 3  cac7cbaf   0006d06b98385729  2020-04-07 00:00:00 2020-04-04
# 4  6b0230bc   00097279a2f46150  2020-11-24 00:00:00 2020-08-02
#
#                 PRODUCT_NAME PRODUCT_ID  USD_PRICE PURCHASE_PLATFORM  \
# 0            Nintendo Switch       e682     168.00           website
# 1            Nintendo Switch       e682     160.61           website
# 2            Nintendo Switch       8d0d     151.20           website
# 3  Sony PlayStation 5 Bundle       54ed    1132.82           website
# 4            Nintendo Switch       8d0d      33.89           website
#
#   MARKETING_CHANNEL ACCOUNT_CREATION_METHOD COUNTRY_CODE
# 0         affiliate                 unknown           US
# ...

# %%
df.dtypes
# Out:
# USER_ID                            object
# ORDER_ID                           object
# PURCHASE time                      object
# SHIP time                  datetime64[ns]
# PRODUCT_NAME                       object
# PRODUCT_ID                         object
# USD_PRICE                         float64
# PURCHASE_PLATFORM                  object
# MARKETING_CHANNEL                  object
# ACCOUNT_CREATION_METHOD            object
# COUNTRY_CODE                       object
# dtype: object

# %%
print(df.columns.tolist())
# Out:
# ['USER_ID', 'ORDER_ID', 'PURCHASE time', 'SHIP time', 'PRODUCT_NAME', 'PRODUCT_ID', 'USD_PRICE', 'PURCHASE_PLATFORM', 'MARKETING_CHANNEL', 'ACCOUNT_CREATION_METHOD', 'COUNTRY_CODE']

# %%
# # Assuming df has columns: 'PRODUCT_NAME' and 'USD_PRICE'
# plt.figure(figsize=(15, 15))
# plt.bar(df['PRODUCT_NAME'], df['USD_PRICE'], color='orange')
# plt.xlabel("Product Name")
# plt.ylabel("Revenue in USD")
# plt.title("Product-wise Revenue from Orders")
# #plt.xticks(rotation=45)  # Rotate labels if they overlap
# #plt.tight_layout()
# plt.show()
